# %%
import pandas as pd #do pracy z danymi w tabelkach
import matplotlib.pyplot as mp #wykresy
import seaborn as sb #bardzije zaawansowane wykresy
import numpy as np #do pracy z macierzami
import datetime #do pracy z datami

# %%
#dane z Meteo

filename = input("Podaj nazwę pliku do wczytani: ")
meteo = pd.read_csv(f"../data/processed/meteo/{filename}")
meteo = meteo.dropna() #usuwamy wiersze z brakującymi danymi

# %%
meteo.info()
meteo.head(20)
#meteo.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   time                  168 non-null    object
#  1   temperature_2m        168 non-null    float64
#  2   relative_humidity_2m  168 non-null    int64
#  3   windspeed_10m         168 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 5.4+ KB
#                 time  temperature_2m  relative_humidity_2m  windspeed_10m
# 0   2025-06-29T00:00            20.9                    61            7.6
# 1   2025-06-29T01:00            20.1                    65            7.2
# 2   2025-06-29T02:00            19.7                    67            8.3
# 3   2025-06-29T03:00            19.0                    70            7.6
# 4   2025-06-29T04:00            19.0                    72            7.9
# 5   2025-06-29T05:00            19.3                    72            9.0
# 6   2025-06-29T06:00            19.8                    70            8.3
# 7   2025-06-29T07:00            20.7                    68            8.6
# 8   2025-06-29T08:00            22.5                    62           13.0
# 9   2025-06-29T09:00            23.8                    61           13.0
# 10  2025-06-29T10:00            25.1                    59           13.7
# 11  2025-06-29T11:00            26.7                    54           16.2
# 12  2025-06-29T12:00            27.1                    50           15.8
# 13  2025-06-29T13:00            28.0                    48           15.8
# 14  2025-06-29T14:00            28.6                    44           16.2
# 15  2025-06-29T15:00            29.0                    42           15.8
# 16  2025-06-29T16:00            29.2                    42           15.5
# 17  2025-06-29T17:00            29.2                    41           15.1
# 18  2025-06-29T18:00            28.8                    40           15.5
# 19  2025-06-29T19:00            28.2                    43           13.0

# %%
meteo.columns
subset = meteo.head(30) #wybieramy pierwsze 50 wierszy

# %%
mp.figure(figsize=(12, 6))
mp.title("Parametry powietrza w czasie (codziennie o 15:00")
mp.xlabel("Czas")
mp.ylabel("Wartość")

import matplotlib.dates as mdates #do zmiany formatu daty na wykresach
# Formatowanie osi X – co 24 godziny
mp.gca().xaxis.set_major_locator(mdates.HourLocator(interval=24))
mp.gca().xaxis.set_major_formatter(mdates.DateFormatter('%d-%m'))


mp.plot(subset["time"], subset["temperature_2m"], label="temperature")
mp.plot(subset["time"], subset["relative_humidity_2m"], label="humidity")
mp.plot(subset["time"], subset["windspeed_10m"], label="windspeed")
mp.legend() 
mp.xticks(rotation=45)
mp.show()
